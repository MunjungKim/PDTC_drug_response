# %%
import pandas as pd

# %% [markdown]
# # information about cell line from drug reponse data

# %%
FILE_CELL_INFO = '../data/secondary-screen-cell-line-info.csv'
cell_info = pd.read_csv(FILE_CELL_INFO)

# %%
cell_info
# Out:
#        row_name   depmap_id                   ccle_name  \
# 0    ACH-000824  ACH-000824          KYSE510_OESOPHAGUS
# 1    ACH-000954  ACH-000954           HEC1A_ENDOMETRIUM
# 2    ACH-000601  ACH-000601           MIAPACA2_PANCREAS
# 3    ACH-000651  ACH-000651       SW620_LARGE_INTESTINE
# 4    ACH-000361  ACH-000361                SKHEP1_LIVER
# ..          ...         ...                         ...
# 583  ACH-001007  ACH-001007    A673STAG2KO16_ENGINEERED
# 584  ACH-001009  ACH-001009    A673STAG2NT14_ENGINEERED
# 585  ACH-000078  ACH-000078   MHHNB11_AUTONOMIC_GANGLIA
# 586  ACH-000366  ACH-000366     SKNDZ_AUTONOMIC_GANGLIA
# 587  ACH-000631  ACH-000631  KS1_CENTRAL_NERVOUS_SYSTEM
#
#                 primary_tissue    secondary_tissue           tertiary_tissue  \
# 0                    esophagus  esophagus_squamous                       NaN
# 1                       uterus  uterus_endometrium                       NaN
# ...

# %%
breast_cell_df = cell_info.loc[cell_info['primary_tissue'] == 'breast']

# %%
breast_cell_list = breast_cell_df['row_name'].tolist()

# %%
print('The number of breast cancer cell line is %d' % len(breast_cell_list))
# Out:
# The number of breast cancer cell line is 27

# %% [markdown]
# # Expression of cell line

# %%
FILE_EXP_CELL = '../data/CCLE_expression_full_19Q4.csv'
exp_cell = pd.read_csv(FILE_EXP_CELL)

# %%
exp_cell
# Out:
#       Unnamed: 0  TSPAN6 (ENSG00000000003)  TNMD (ENSG00000000005)  \
# 0     ACH-001097                  0.000000                0.000000
# 1     ACH-001804                  4.934988                0.000000
# 2     ACH-000534                  0.839960                0.000000
# 3     ACH-000742                  3.722466                0.000000
# 4     ACH-000836                  4.632268                0.000000
# ...          ...                       ...                     ...
# 1244  ACH-000904                  4.316870                0.028569
# 1245  ACH-000110                  5.227279                0.070389
# 1246  ACH-000261                  4.447579                0.028569
# 1247  ACH-000031                  4.714795                0.028569
# 1248  ACH-000682                  5.976364                0.124328
#
#       DPM1 (ENSG00000000419)  SCYL3 (ENSG00000000457)  \
# 0                   4.667324                 1.761285
# ...

# %%
exp_cell = exp_cell.set_index('Unnamed: 0').T

# %%
exp_cell
# Out:
# Unnamed: 0                    ACH-001097  ACH-001804  ACH-000534  ACH-000742  \
# TSPAN6 (ENSG00000000003)        0.000000    4.934988    0.839960    3.722466
# TNMD (ENSG00000000005)          0.000000    0.000000    0.000000    0.000000
# DPM1 (ENSG00000000419)          4.667324    6.635464    5.376082    6.029674
# SCYL3 (ENSG00000000457)         1.761285    1.929791    2.687061    2.192194
# C1orf112 (ENSG00000000460)      3.554589    2.503349    4.440288    2.533563
# ...                                  ...         ...         ...         ...
# AL589743.7 (ENSG00000285990)    0.000000    0.000000    1.084064    0.000000
# AL355312.5 (ENSG00000285991)    0.000000    0.298658    0.000000    0.604071
# AC120036.5 (ENSG00000285992)    0.000000    0.000000    0.000000    0.000000
# AC018931.1 (ENSG00000285993)    0.000000    0.000000    0.000000    0.000000
# AL731559.1 (ENSG00000285994)    0.000000    0.000000    0.000000    0.000000
#
# ...

# %%
exp_breast = exp_cell[breast_cell_list]

# %%
exp_breast
# Out:
# Unnamed: 0                    ACH-000147  ACH-000624  ACH-000028  ACH-000277  \
# TSPAN6 (ENSG00000000003)        3.975447    4.242603    2.636915    1.495695
# TNMD (ENSG00000000005)          0.000000    0.000000    0.000000    0.000000
# DPM1 (ENSG00000000419)          6.733761    5.393004    6.789599    8.396776
# SCYL3 (ENSG00000000457)         2.739848    1.713696    2.819668    3.353323
# C1orf112 (ENSG00000000460)      4.128458    2.411426    3.730096    4.185867
# ...                                  ...         ...         ...         ...
# AL589743.7 (ENSG00000285990)    0.000000    0.000000    0.000000    0.000000
# AL355312.5 (ENSG00000285991)    0.485427    0.641546    0.150560    0.604071
# AC120036.5 (ENSG00000285992)    0.000000    0.000000    0.070389    0.000000
# AC018931.1 (ENSG00000285993)    0.000000    0.000000    0.028569    0.000000
# AL731559.1 (ENSG00000285994)    0.000000    0.000000    0.084064    0.084064
#
# ...

# %%
exp_breast.to_csv('../data/CCLE_expression_full_19Q4_breast.csv')

# %% [markdown]
# # Drug response of cell line

# %%
FILE_RES_CELL = '../data/secondary-screen-dose-response-curve-parameters.csv'
response_cell = pd.read_csv(FILE_RES_CELL)
# Out:
# C:\Users\sbi-student\anaconda3\envs\torch_jupyter\lib\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
response_cell
# Out:
#                       broad_id   depmap_id           ccle_name screen_id  \
# 0       BRD-K71847383-001-12-5  ACH-000879  MFE296_ENDOMETRIUM    HTS002
# 1       BRD-K71847383-001-12-5  ACH-000320       PSN1_PANCREAS    HTS002
# 2       BRD-K71847383-001-12-5  ACH-001145         OC316_OVARY    HTS002
# 3       BRD-K71847383-001-12-5  ACH-000873  KYSE270_OESOPHAGUS    HTS002
# 4       BRD-K71847383-001-12-5  ACH-000855  KYSE150_OESOPHAGUS    HTS002
# ...                        ...         ...                 ...       ...
# 700999  BRD-K96123349-236-02-8  ACH-001321          TT_THYROID    MTS010
# 701000  BRD-K98572433-001-02-9  ACH-001321          TT_THYROID    MTS010
# 701001  BRD-K99113996-001-02-0  ACH-001321          TT_THYROID    MTS010
# 701002  BRD-K99616396-001-05-1  ACH-001321          TT_THYROID    MTS010
# 701003  BRD-M97302542-001-04-4  ACH-001321          TT_THYROID    MTS010
#
#         upper_limit  lower_limit     slope        r2       auc          ec50  \
# ...

# %%
response_cell_abstract = response_cell[['row_name', 'smiles', 'auc']]

# %%
response_cell_abstract
# Out:
#           row_name                                             smiles  \
# 0       ACH-000879  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 1       ACH-000320  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 2       ACH-001145  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 3       ACH-000873  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 4       ACH-000855  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# ...            ...                                                ...
# 700999  ACH-001321    Cc1c(nc2ccc(F)cc2c1C(O)=O)-c1ccc(cc1)-c1ccccc1F
# 701000  ACH-001321  CNC(=O)CN1CCC(CC1)Oc1cc2c(Nc3cccc(Cl)c3F)ncnc2...
# 701001  ACH-001321  CNC(=O)c1cccc(c1)-c1ccc2c(nc(nc2n1)N1CCOC[C@@H...
# 701002  ACH-001321  CC1(C)CNc2cc(NC(=O)c3cccnc3NCc3ccncc3)ccc12, C...
# 701003  ACH-001321             [Na].OC(=O)C(Cl)Cl, [Na].OC(=O)C(Cl)Cl
#
#              auc
# 0       1.677789
# 1       1.240300
# 2       1.472333
# 3       1.207160
# 4       1.229332
# ...

# %%
response_cell_abstract_breast = response_cell_abstract[response_cell_abstract['row_name'].isin(breast_cell_list)]

# %%
response_cell_abstract_breast
# Out:
#           row_name                                             smiles  \
# 27      ACH-000212  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 32      ACH-000856  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 47      ACH-000711  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 69      ACH-000643  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# 73      ACH-000019  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...
# ...            ...                                                ...
# 693648  ACH-000927  CNC(=O)CN1CCC(CC1)Oc1cc2c(Nc3cccc(Cl)c3F)ncnc2...
# 693649  ACH-000927  CNC(=O)c1cccc(c1)-c1ccc2c(nc(nc2n1)N1CCOC[C@@H...
# 693650  ACH-000927  CC1(C)CNc2cc(NC(=O)c3cccnc3NCc3ccncc3)ccc12, C...
# 693651  ACH-000927  Cc1ccc(F)c(NC(=O)Nc2ccc(cc2)-c2cccc3[nH]nc(N)c...
# 693652  ACH-000927             [Na].OC(=O)C(Cl)Cl, [Na].OC(=O)C(Cl)Cl
#
#              auc
# 27      1.111354
# 32      1.320316
# 47      1.420198
# 69      1.229564
# 73      1.117433
# ...

# %%
response_cell_abstract_breast.to_csv('../data/secondary-screen-dose-response-curve-parameters_breast.csv')

# %%
response_cell_breast = response_cell[response_cell['row_name'].isin(breast_cell_listas)]
