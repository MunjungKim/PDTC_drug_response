# %%
import pandas as pd

# %%
drug_res_model = pd.read_csv('/home/munj/PDTC_drug_response/data/DrugResponsesAUCModels.txt', sep = "\t",  engine='python', encoding = "cp949")

# %%
drug_res_model
# Out:
#         Model               Drug       AUC               iC50     D1_CONC  \
# 0      HCI001  (5Z)-7-Oxozeaenol  0.217813   5.48327034751385    7.701322
# 1      HCI001             17-AAG  0.301919   18349.7411361244    1.000000
# 2      HCI001     5-Fluorouracil  0.494210    1.3502642314527   20.000000
# 3      HCI001             681640  0.102932    152.12579956481    2.000000
# 4      HCI001            ABT-263  0.497307  0.124656353895025    2.000000
# ...       ...                ...       ...                ...         ...
# 1631  VHIO244         Vorinostat  0.560835  0.478323131822251   10.000000
# 1632  VHIO244            XAV 939  0.080441   103327.052987666    5.581430
# 1633  VHIO244           YK 4-279  0.216032   8.69091078926115    7.701322
# 1634  VHIO244          ZM-447439  0.127893   1493729.57804505    3.275568
# 1635  VHIO244              mirin  0.245509   39.4077095447554  100.000000
#
#        D5_CONC   perc.iC50
# 0     2.337740   71.507443
# 1     0.003906  183.038003
# 2     0.078125   51.391421
# 3     0.007812  150.681089
# 4     0.007812   49.591347
# ...        ...         ...
# 1631  0.039062   44.636232
# 1632  1.175631  702.942004
# 1633  2.337740   79.903643
# 1634  0.740057  587.743723
# 1635  0.390625   80.132887
#
# [1636 rows x 7 columns]
